# %% [markdown]
# ## Visualize Data: Tiny-NeRF

# %%
# !wget https://people.eecs.berkeley.edu/~bmild/nerf/tiny_nerf_data.npz
# Out:
# --2022-08-16 08:27:43--  https://people.eecs.berkeley.edu/~bmild/nerf/tiny_nerf_data.npz
# 正在解析主机 people.eecs.berkeley.edu (people.eecs.berkeley.edu)... 128.32.244.190
# 正在连接 people.eecs.berkeley.edu (people.eecs.berkeley.edu)|128.32.244.190|:443... 已连接。
# 已发出 HTTP 请求，正在等待回应... 301 Moved Permanently
# 位置：https://bmild.com/nerf/tiny_nerf_data.npz [跟随至新的 URL]
# --2022-08-16 08:27:43--  https://bmild.com/nerf/tiny_nerf_data.npz
# 正在解析主机 bmild.com (bmild.com)... 216.239.36.21, 216.239.32.21, 216.239.38.21, ...
# 正在连接 bmild.com (bmild.com)|216.239.36.21|:443... 已连接。
# 已发出 HTTP 请求，正在等待回应... 302 Found
# 位置：https://bmild.github.io/nerf/tiny_nerf_data.npz [跟随至新的 URL]
# --2022-08-16 08:27:43--  https://bmild.github.io/nerf/tiny_nerf_data.npz
# 正在解析主机 bmild.github.io (bmild.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# 正在连接 bmild.github.io (bmild.github.io)|185.199.108.153|:443... 已连接。
# 已发出 HTTP 请求，正在等待回应... 200 OK
# 长度：12727482 (12M) [application/octet-stream]
# 正在保存至: “tiny_nerf_data.npz”
#
# tiny_nerf_data.npz  100%[===================>]  12.14M  20.2MB/s  用时 0.6s
#
# 2022-08-16 08:27:45 (20.2 MB/s) - 已保存 “tiny_nerf_data.npz” [12727482/12727482])

# %%
# Use the Tiny-NeRF dataset (a subset of the original Blender dataset)
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid

# %%
data = np.load("tiny_nerf_data.npz")
images = data["images"]
poses = data["poses"]
focal = float(data["focal"])

_, image_height, image_width, _ = images.shape

# We would use the first 100 images, poses as training data
train_images, train_poses = images[:100], poses[:100]
# We use a single image, pose pair for validation
val_image, val_pose = images[101], poses[101]

# Visualize the training data
fig = plt.figure(figsize=(16, 16))
grid = ImageGrid(fig, 111, nrows_ncols=(4, 4), axes_pad=0.1)
random_images = images[np.random.choice(np.arange(images.shape[0]), 16)]
for ax, image in zip(grid, random_images):
    ax.imshow(image)
plt.title("Sample Images from Tiny-NeRF Data")
plt.show()

# %%
print(images.shape)
print(focal)
print(poses.shape)

print(poses[0])
# Out:
# (106, 100, 100, 3)
# 138.88887889922103
# (106, 4, 4)
# [[-9.9990219e-01  4.1922452e-03 -1.3345719e-02 -5.3798322e-02]
#  [-1.3988681e-02 -2.9965907e-01  9.5394367e-01  3.8454704e+00]
#  [-4.6566129e-10  9.5403719e-01  2.9968831e-01  1.2080823e+00]
#  [ 0.0000000e+00  0.0000000e+00  0.0000000e+00  1.0000000e+00]]
